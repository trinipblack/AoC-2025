# %%
import numpy as np
from time import time
from tqdm import tqdm
from loguru import logger
import sys

# %%
raw_data = open('files/input_day7.txt').read()

# %%
example = '''.......S.......
...............
.......^.......
...............
......^.^......
...............
.....^.^.^.....
...............
....^.^...^....
...............
...^.^...^.^...
...............
..^...^.....^..
...............
.^.^.^.^.^...^.
...............'''

# %%
class TachyonManifolds:
    def __init__(self, raw_data, is_example = False):
        self.is_example = is_example
        self.diagram = self.preprocess(raw_data)
        self.start = self.find_start()
        self.n_splitted = 0

    def preprocess(self, data):    
        return data.strip().split('\n')

    def find_start(self):
        for i, row in enumerate(self.diagram):
            if 'S' in row:
                return i, row.index('S')
    
    def find_beams_in_row(self, row):
        return [i for i, c in enumerate(row) if c == '|']

    def set_beam(self, r, c):
        l = self.diagram[r]
        self.diagram[r] = l[:c] + '|' + l[c+1:]

    def forward_beam(self, r, c):
        if r == len(self.diagram) - 1:
            return
        is_splitter = self.diagram[r+1][c] == '^'
        if is_splitter:
            if c-1 >= 0:
                self.set_beam(r+1, c-1)
            if c+1 < len(self.diagram):
                self.set_beam(r+1, c+1)
            self.n_splitted += 1
        else:
            self.set_beam(r+1, c)

    def analyze(self):
        logger.remove()
        if self.is_example:
            logger.add(sys.stderr, level="DEBUG")
        else:
            logger.add(sys.stderr, level="INFO")
        t_start = time()

        # Set starting beam
        self.set_beam(self.start[0]+1, self.start[1])
        # Loop through rows
        for r, row in enumerate(self.diagram):
            beams_in_row = self.find_beams_in_row(row)
            for c in beams_in_row:
                self.forward_beam(r, c)
            logger.debug('\n'+'\n'.join(self.diagram))
            logger.debug(f'Splitted now {self.n_splitted} times')

        t_end = time()
        logger.info(f'Part 1 took: {(t_end-t_start)*1000:.2f}ms')
        logger.info(f'Result is n times splitted {self.n_splitted}')

ex_man = TachyonManifolds(example, is_example = True)
ex_man.analyze()
# Out:
# 2025-12-08 15:33:14.824 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# .......^.......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.825 | DEBUG    | __main__:analyze:52 - Splitted now 0 times
# 2025-12-08 15:33:14.825 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.825 | DEBUG    | __main__:analyze:52 - Splitted now 1 times
# 2025-12-08 15:33:14.825 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.825 | DEBUG    | __main__:analyze:52 - Splitted now 1 times
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:52 - Splitted now 3 times
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:52 - Splitted now 3 times
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.826 | DEBUG    | __main__:analyze:52 - Splitted now 6 times
# 2025-12-08 15:33:14.827 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.827 | DEBUG    | __main__:analyze:52 - Splitted now 6 times
# 2025-12-08 15:33:14.827 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.827 | DEBUG    | __main__:analyze:52 - Splitted now 9 times
# 2025-12-08 15:33:14.827 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:52 - Splitted now 9 times
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:52 - Splitted now 13 times
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:52 - Splitted now 13 times
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:52 - Splitted now 16 times
# 2025-12-08 15:33:14.828 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:52 - Splitted now 16 times
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# ...............
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:52 - Splitted now 21 times
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# |.|.|.|.|.|||.|
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:52 - Splitted now 21 times
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:51 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# |.|.|.|.|.|||.|
# 2025-12-08 15:33:14.829 | DEBUG    | __main__:analyze:52 - Splitted now 21 times
# 2025-12-08 15:33:14.829 | INFO     | __main__:analyze:55 - Part 1 took: 5.11ms
# 2025-12-08 15:33:14.830 | INFO     | __main__:analyze:56 - Result is n times splitted 21

# %%
ex_man = TachyonManifolds(raw_data)
ex_man.analyze()
# Out:
# 2025-12-08 15:33:14.842 | INFO     | __main__:analyze:55 - Part 1 took: 2.38ms
# 2025-12-08 15:33:14.842 | INFO     | __main__:analyze:56 - Result is n times splitted 1560
