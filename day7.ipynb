# %%
import numpy as np
from time import time
from loguru import logger
import sys

# %%
raw_data = open('files/input_day7.txt').read()

# %%
example = '''.......S.......
...............
.......^.......
...............
......^.^......
...............
.....^.^.^.....
...............
....^.^...^....
...............
...^.^...^.^...
...............
..^...^.....^..
...............
.^.^.^.^.^...^.
...............'''

# %%
class TachyonManifold:
    def __init__(self, raw_data, is_example = False):
        self.is_example = is_example
        logger.remove()
        if self.is_example:
            logger.add(sys.stderr, level="DEBUG")
        else:
            logger.add(sys.stderr, level="INFO")
        self.diagram = self.preprocess(raw_data)
        self.start = self.find_start()
        self.n_splitted = 0

    def preprocess(self, data):    
        return data.strip().split('\n')

    def find_start(self):
        for i, row in enumerate(self.diagram):
            if 'S' in row:
                return i, row.index('S')
    
    def find_beams_in_row(self, row):
        return [i for i, c in enumerate(row) if c == '|']

    def set_beam(self, r, c):
        l = self.diagram[r]
        self.diagram[r] = l[:c] + '|' + l[c+1:]

    def forward_beam(self, r, c):
        if r == len(self.diagram) - 1:
            return
        is_splitter = self.diagram[r+1][c] == '^'
        if is_splitter:
            if c-1 >= 0:
                self.set_beam(r+1, c-1)
            if c+1 < len(self.diagram):
                self.set_beam(r+1, c+1)
            self.n_splitted += 1
            logger.debug(f'Splitted now {self.n_splitted} times')
        else:
            self.set_beam(r+1, c)

    def analyze(self):
        t_start = time()

        # Set starting beam
        self.set_beam(self.start[0]+1, self.start[1])
        # Loop through rows
        for r, row in enumerate(self.diagram):
            beams_in_row = self.find_beams_in_row(row)
            for c in beams_in_row:
                self.forward_beam(r, c)
            logger.debug('\n'+'\n'.join(self.diagram))

        t_end = time()
        logger.info(f'Part 1 took: {(t_end-t_start)*1000:.2f}ms')
        logger.info(f'Result is n times splitted {self.n_splitted}')

ex_man = TachyonManifold(example, is_example = True)
ex_man.analyze()
# Out:
# 2025-12-08 17:51:46.692 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# .......^.......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.692 | DEBUG    | __main__:forward_beam:38 - Splitted now 1 times
# 2025-12-08 17:51:46.692 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.693 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.693 | DEBUG    | __main__:forward_beam:38 - Splitted now 2 times
# 2025-12-08 17:51:46.693 | DEBUG    | __main__:forward_beam:38 - Splitted now 3 times
# 2025-12-08 17:51:46.693 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.694 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.694 | DEBUG    | __main__:forward_beam:38 - Splitted now 4 times
# 2025-12-08 17:51:46.694 | DEBUG    | __main__:forward_beam:38 - Splitted now 5 times
# 2025-12-08 17:51:46.694 | DEBUG    | __main__:forward_beam:38 - Splitted now 6 times
# 2025-12-08 17:51:46.695 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.695 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.695 | DEBUG    | __main__:forward_beam:38 - Splitted now 7 times
# 2025-12-08 17:51:46.695 | DEBUG    | __main__:forward_beam:38 - Splitted now 8 times
# 2025-12-08 17:51:46.695 | DEBUG    | __main__:forward_beam:38 - Splitted now 9 times
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:forward_beam:38 - Splitted now 10 times
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:forward_beam:38 - Splitted now 11 times
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:forward_beam:38 - Splitted now 12 times
# 2025-12-08 17:51:46.696 | DEBUG    | __main__:forward_beam:38 - Splitted now 13 times
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:forward_beam:38 - Splitted now 14 times
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:forward_beam:38 - Splitted now 15 times
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:forward_beam:38 - Splitted now 16 times
# 2025-12-08 17:51:46.697 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:forward_beam:38 - Splitted now 17 times
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:forward_beam:38 - Splitted now 18 times
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:forward_beam:38 - Splitted now 19 times
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:forward_beam:38 - Splitted now 20 times
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:forward_beam:38 - Splitted now 21 times
# 2025-12-08 17:51:46.698 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# ...............
# 2025-12-08 17:51:46.699 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# |.|.|.|.|.|||.|
# 2025-12-08 17:51:46.699 | DEBUG    | __main__:analyze:52 -
# .......S.......
# .......|.......
# ......|^|......
# ......|.|......
# .....|^|^|.....
# .....|.|.|.....
# ....|^|^|^|....
# ....|.|.|.|....
# ...|^|^|||^|...
# ...|.|.|||.|...
# ..|^|^|||^|^|..
# ..|.|.|||.|.|..
# .|^|||^||.||^|.
# .|.|||.||.||.|.
# |^|^|^|^|^|||^|
# |.|.|.|.|.|||.|
# 2025-12-08 17:51:46.699 | INFO     | __main__:analyze:55 - Part 1 took: 7.25ms
# 2025-12-08 17:51:46.699 | INFO     | __main__:analyze:56 - Result is n times splitted 21

# %%
man = TachyonManifold(raw_data, is_example = False)
man.analyze()
# Out:
# 2025-12-08 17:51:46.709 | INFO     | __main__:analyze:55 - Part 1 took: 3.03ms
# 2025-12-08 17:51:46.709 | INFO     | __main__:analyze:56 - Result is n times splitted 1560

# %% [markdown]
# # Part 2

# %%
class QuantumTachyonManifold:
    def __init__(self, raw_data, is_example = False):
        self.is_example = is_example
        logger.remove()
        if self.is_example:
            logger.add(sys.stderr, level="DEBUG")
        else:
            logger.add(sys.stderr, level="INFO")
        self.diagram = self.preprocess(raw_data)
        self.start = self.find_start()
        self.n_splitted = 0

    def preprocess(self, data):    
        return [list(row) for row in data.strip().split('\n')]

    def find_start(self):
        for i, row in enumerate(self.diagram):
            if 'S' in row:
                return i, row.index('S')
    
    def find_beams_in_row(self, row):
        return [i for i, c in enumerate(row) if c != '^' and c != '.' and c != 'S']

    def set_beam(self, r, c, mult:int = 1):
        l = self.diagram[r]
        if l[c] == '.' or l[c] == 'S':
            n_beans = mult
        elif l[c] == '^':
            logger.error('WTF')
        else:
            n_beans = int(l[c]) + mult
        new_n_beans_str = str(n_beans)
        self.diagram[r][c] = new_n_beans_str

    def forward_beam(self, r, c):
        if r == len(self.diagram) - 1:
            return
        is_splitter = self.diagram[r+1][c] == '^'
        beam_mult = int(self.diagram[r][c])
        if is_splitter:
            if c-1 >= 0:
                self.set_beam(r+1, c-1, beam_mult)
            if c+1 < len(self.diagram):
                self.set_beam(r+1, c+1, beam_mult)
            self.n_splitted += 1
            logger.debug(f'Splitted now {self.n_splitted} times')
        else:
            self.set_beam(r+1, c, beam_mult)


    def analyze(self):
        t_start = time()

        # Set starting beam
        self.set_beam(self.start[0]+1, self.start[1], 1)
        self.show_diagram()
        # Loop through rows
        for r, row in enumerate(self.diagram):
            if r == 0:
                continue
            logger.debug(f'Analyzing row {r}: {row}')
            pos_of_beams_in_row = self.find_beams_in_row(row)
            timelines_list = [int(row[pos]) for pos in pos_of_beams_in_row]
            timelines = sum(timelines_list)
            logger.debug(f'Row has beams {timelines_list} so timelines up to now are {timelines}')
            for c in pos_of_beams_in_row:
                logger.debug(f'Beam in pos {r, c} is {self.diagram[r][c]}')
                self.forward_beam(r, c)
            self.show_diagram()

        t_end = time()
        logger.info(f'Part 2 took: {(t_end-t_start)*1000:.2f}ms')
        logger.info(f'Result is n timelines = {timelines}')

    def show_diagram(self):
        logger.debug('\n'+'\n'.join([''.join(row) for row in self.diagram]))

ex_man = QuantumTachyonManifold(example, is_example = True)
ex_man.show_diagram()
# Out:
# 2025-12-08 18:30:22.403 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# ...............
# .......^.......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............

# %%
ex_man.analyze()
# Out:
# 2025-12-08 18:30:23.765 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# .......^.......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.766 | DEBUG    | __main__:analyze:61 - Analyzing row 1: ['.', '.', '.', '.', '.', '.', '.', '1', '.', '.', '.', '.', '.', '.', '.']
# 2025-12-08 18:30:23.766 | DEBUG    | __main__:analyze:65 - Row has beams [1] so timelines up to now are 1
# 2025-12-08 18:30:23.767 | DEBUG    | __main__:analyze:67 - Beam in pos (1, 7) is 1
# 2025-12-08 18:30:23.767 | DEBUG    | __main__:forward_beam:46 - Splitted now 1 times
# 2025-12-08 18:30:23.767 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.768 | DEBUG    | __main__:analyze:61 - Analyzing row 2: ['.', '.', '.', '.', '.', '.', '1', '^', '1', '.', '.', '.', '.', '.', '.']
# 2025-12-08 18:30:23.768 | DEBUG    | __main__:analyze:65 - Row has beams [1, 1] so timelines up to now are 2
# 2025-12-08 18:30:23.769 | DEBUG    | __main__:analyze:67 - Beam in pos (2, 6) is 1
# 2025-12-08 18:30:23.769 | DEBUG    | __main__:analyze:67 - Beam in pos (2, 8) is 1
# 2025-12-08 18:30:23.769 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.770 | DEBUG    | __main__:analyze:61 - Analyzing row 3: ['.', '.', '.', '.', '.', '.', '1', '.', '1', '.', '.', '.', '.', '.', '.']
# 2025-12-08 18:30:23.770 | DEBUG    | __main__:analyze:65 - Row has beams [1, 1] so timelines up to now are 2
# 2025-12-08 18:30:23.770 | DEBUG    | __main__:analyze:67 - Beam in pos (3, 6) is 1
# 2025-12-08 18:30:23.770 | DEBUG    | __main__:forward_beam:46 - Splitted now 2 times
# 2025-12-08 18:30:23.770 | DEBUG    | __main__:analyze:67 - Beam in pos (3, 8) is 1
# 2025-12-08 18:30:23.771 | DEBUG    | __main__:forward_beam:46 - Splitted now 3 times
# 2025-12-08 18:30:23.771 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.771 | DEBUG    | __main__:analyze:61 - Analyzing row 4: ['.', '.', '.', '.', '.', '1', '^', '2', '^', '1', '.', '.', '.', '.', '.']
# 2025-12-08 18:30:23.771 | DEBUG    | __main__:analyze:65 - Row has beams [1, 2, 1] so timelines up to now are 4
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:analyze:67 - Beam in pos (4, 5) is 1
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:analyze:67 - Beam in pos (4, 7) is 2
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:analyze:67 - Beam in pos (4, 9) is 1
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:analyze:61 - Analyzing row 5: ['.', '.', '.', '.', '.', '1', '.', '2', '.', '1', '.', '.', '.', '.', '.']
# 2025-12-08 18:30:23.772 | DEBUG    | __main__:analyze:65 - Row has beams [1, 2, 1] so timelines up to now are 4
# 2025-12-08 18:30:23.773 | DEBUG    | __main__:analyze:67 - Beam in pos (5, 5) is 1
# 2025-12-08 18:30:23.773 | DEBUG    | __main__:forward_beam:46 - Splitted now 4 times
# 2025-12-08 18:30:23.773 | DEBUG    | __main__:analyze:67 - Beam in pos (5, 7) is 2
# 2025-12-08 18:30:23.773 | DEBUG    | __main__:forward_beam:46 - Splitted now 5 times
# 2025-12-08 18:30:23.773 | DEBUG    | __main__:analyze:67 - Beam in pos (5, 9) is 1
# 2025-12-08 18:30:23.774 | DEBUG    | __main__:forward_beam:46 - Splitted now 6 times
# 2025-12-08 18:30:23.774 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.774 | DEBUG    | __main__:analyze:61 - Analyzing row 6: ['.', '.', '.', '.', '1', '^', '3', '^', '3', '^', '1', '.', '.', '.', '.']
# 2025-12-08 18:30:23.774 | DEBUG    | __main__:analyze:65 - Row has beams [1, 3, 3, 1] so timelines up to now are 8
# 2025-12-08 18:30:23.774 | DEBUG    | __main__:analyze:67 - Beam in pos (6, 4) is 1
# 2025-12-08 18:30:23.775 | DEBUG    | __main__:analyze:67 - Beam in pos (6, 6) is 3
# 2025-12-08 18:30:23.775 | DEBUG    | __main__:analyze:67 - Beam in pos (6, 8) is 3
# 2025-12-08 18:30:23.775 | DEBUG    | __main__:analyze:67 - Beam in pos (6, 10) is 1
# 2025-12-08 18:30:23.775 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.775 | DEBUG    | __main__:analyze:61 - Analyzing row 7: ['.', '.', '.', '.', '1', '.', '3', '.', '3', '.', '1', '.', '.', '.', '.']
# 2025-12-08 18:30:23.776 | DEBUG    | __main__:analyze:65 - Row has beams [1, 3, 3, 1] so timelines up to now are 8
# 2025-12-08 18:30:23.776 | DEBUG    | __main__:analyze:67 - Beam in pos (7, 4) is 1
# 2025-12-08 18:30:23.776 | DEBUG    | __main__:forward_beam:46 - Splitted now 7 times
# 2025-12-08 18:30:23.776 | DEBUG    | __main__:analyze:67 - Beam in pos (7, 6) is 3
# 2025-12-08 18:30:23.777 | DEBUG    | __main__:forward_beam:46 - Splitted now 8 times
# 2025-12-08 18:30:23.777 | DEBUG    | __main__:analyze:67 - Beam in pos (7, 8) is 3
# 2025-12-08 18:30:23.777 | DEBUG    | __main__:analyze:67 - Beam in pos (7, 10) is 1
# 2025-12-08 18:30:23.777 | DEBUG    | __main__:forward_beam:46 - Splitted now 9 times
# 2025-12-08 18:30:23.777 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:61 - Analyzing row 8: ['.', '.', '.', '1', '^', '4', '^', '3', '3', '1', '^', '1', '.', '.', '.']
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:65 - Row has beams [1, 4, 3, 3, 1, 1] so timelines up to now are 13
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 3) is 1
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 5) is 4
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 7) is 3
# 2025-12-08 18:30:23.778 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 8) is 3
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 9) is 1
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:analyze:67 - Beam in pos (8, 11) is 1
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:analyze:61 - Analyzing row 9: ['.', '.', '.', '1', '.', '4', '.', '3', '3', '1', '.', '1', '.', '.', '.']
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:analyze:65 - Row has beams [1, 4, 3, 3, 1, 1] so timelines up to now are 13
# 2025-12-08 18:30:23.779 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 3) is 1
# 2025-12-08 18:30:23.780 | DEBUG    | __main__:forward_beam:46 - Splitted now 10 times
# 2025-12-08 18:30:23.780 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 5) is 4
# 2025-12-08 18:30:23.780 | DEBUG    | __main__:forward_beam:46 - Splitted now 11 times
# 2025-12-08 18:30:23.780 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 7) is 3
# 2025-12-08 18:30:23.780 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 8) is 3
# 2025-12-08 18:30:23.781 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 9) is 1
# 2025-12-08 18:30:23.781 | DEBUG    | __main__:forward_beam:46 - Splitted now 12 times
# 2025-12-08 18:30:23.781 | DEBUG    | __main__:analyze:67 - Beam in pos (9, 11) is 1
# 2025-12-08 18:30:23.781 | DEBUG    | __main__:forward_beam:46 - Splitted now 13 times
# 2025-12-08 18:30:23.781 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:61 - Analyzing row 10: ['.', '.', '1', '^', '5', '^', '4', '3', '4', '^', '2', '^', '1', '.', '.']
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:65 - Row has beams [1, 5, 4, 3, 4, 2, 1] so timelines up to now are 20
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 2) is 1
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 4) is 5
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 6) is 4
# 2025-12-08 18:30:23.782 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 7) is 3
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 8) is 4
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 10) is 2
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:analyze:67 - Beam in pos (10, 12) is 1
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:analyze:61 - Analyzing row 11: ['.', '.', '1', '.', '5', '.', '4', '3', '4', '.', '2', '.', '1', '.', '.']
# 2025-12-08 18:30:23.783 | DEBUG    | __main__:analyze:65 - Row has beams [1, 5, 4, 3, 4, 2, 1] so timelines up to now are 20
# 2025-12-08 18:30:23.784 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 2) is 1
# 2025-12-08 18:30:23.784 | DEBUG    | __main__:forward_beam:46 - Splitted now 14 times
# 2025-12-08 18:30:23.784 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 4) is 5
# 2025-12-08 18:30:23.784 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 6) is 4
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:forward_beam:46 - Splitted now 15 times
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 7) is 3
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 8) is 4
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 10) is 2
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:analyze:67 - Beam in pos (11, 12) is 1
# 2025-12-08 18:30:23.785 | DEBUG    | __main__:forward_beam:46 - Splitted now 16 times
# 2025-12-08 18:30:23.786 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# .1^154^74.21^1.
# ...............
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.786 | DEBUG    | __main__:analyze:61 - Analyzing row 12: ['.', '1', '^', '1', '5', '4', '^', '7', '4', '.', '2', '1', '^', '1', '.']
# 2025-12-08 18:30:23.786 | DEBUG    | __main__:analyze:65 - Row has beams [1, 1, 5, 4, 7, 4, 2, 1, 1] so timelines up to now are 26
# 2025-12-08 18:30:23.786 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 1) is 1
# 2025-12-08 18:30:23.786 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 3) is 1
# 2025-12-08 18:30:23.787 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 4) is 5
# 2025-12-08 18:30:23.787 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 5) is 4
# 2025-12-08 18:30:23.787 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 7) is 7
# 2025-12-08 18:30:23.787 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 8) is 4
# 2025-12-08 18:30:23.787 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 10) is 2
# 2025-12-08 18:30:23.788 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 11) is 1
# 2025-12-08 18:30:23.788 | DEBUG    | __main__:analyze:67 - Beam in pos (12, 13) is 1
# 2025-12-08 18:30:23.788 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# .1^154^74.21^1.
# .1.154.74.21.1.
# .^.^.^.^.^...^.
# ...............
# 2025-12-08 18:30:23.788 | DEBUG    | __main__:analyze:61 - Analyzing row 13: ['.', '1', '.', '1', '5', '4', '.', '7', '4', '.', '2', '1', '.', '1', '.']
# 2025-12-08 18:30:23.789 | DEBUG    | __main__:analyze:65 - Row has beams [1, 1, 5, 4, 7, 4, 2, 1, 1] so timelines up to now are 26
# 2025-12-08 18:30:23.789 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 1) is 1
# 2025-12-08 18:30:23.789 | DEBUG    | __main__:forward_beam:46 - Splitted now 17 times
# 2025-12-08 18:30:23.789 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 3) is 1
# 2025-12-08 18:30:23.789 | DEBUG    | __main__:forward_beam:46 - Splitted now 18 times
# 2025-12-08 18:30:23.790 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 4) is 5
# 2025-12-08 18:30:23.790 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 5) is 4
# 2025-12-08 18:30:23.790 | DEBUG    | __main__:forward_beam:46 - Splitted now 19 times
# 2025-12-08 18:30:23.790 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 7) is 7
# 2025-12-08 18:30:23.790 | DEBUG    | __main__:forward_beam:46 - Splitted now 20 times
# 2025-12-08 18:30:23.791 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 8) is 4
# 2025-12-08 18:30:23.791 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 10) is 2
# 2025-12-08 18:30:23.791 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 11) is 1
# 2025-12-08 18:30:23.791 | DEBUG    | __main__:analyze:67 - Beam in pos (13, 13) is 1
# 2025-12-08 18:30:23.792 | DEBUG    | __main__:forward_beam:46 - Splitted now 21 times
# 2025-12-08 18:30:23.792 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# .1^154^74.21^1.
# .1.154.74.21.1.
# 1^2^10^11^11^211^1
# ...............
# 2025-12-08 18:30:23.792 | DEBUG    | __main__:analyze:61 - Analyzing row 14: ['1', '^', '2', '^', '10', '^', '11', '^', '11', '^', '2', '1', '1', '^', '1']
# 2025-12-08 18:30:23.792 | DEBUG    | __main__:analyze:65 - Row has beams [1, 2, 10, 11, 11, 2, 1, 1, 1] so timelines up to now are 40
# 2025-12-08 18:30:23.792 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 0) is 1
# 2025-12-08 18:30:23.793 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 2) is 2
# 2025-12-08 18:30:23.793 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 4) is 10
# 2025-12-08 18:30:23.793 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 6) is 11
# 2025-12-08 18:30:23.793 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 8) is 11
# 2025-12-08 18:30:23.794 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 10) is 2
# 2025-12-08 18:30:23.794 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 11) is 1
# 2025-12-08 18:30:23.794 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 12) is 1
# 2025-12-08 18:30:23.794 | DEBUG    | __main__:analyze:67 - Beam in pos (14, 14) is 1
# 2025-12-08 18:30:23.794 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# .1^154^74.21^1.
# .1.154.74.21.1.
# 1^2^10^11^11^211^1
# 1.2.10.11.11.211.1
# 2025-12-08 18:30:23.795 | DEBUG    | __main__:analyze:61 - Analyzing row 15: ['1', '.', '2', '.', '10', '.', '11', '.', '11', '.', '2', '1', '1', '.', '1']
# 2025-12-08 18:30:23.795 | DEBUG    | __main__:analyze:65 - Row has beams [1, 2, 10, 11, 11, 2, 1, 1, 1] so timelines up to now are 40
# 2025-12-08 18:30:23.795 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 0) is 1
# 2025-12-08 18:30:23.795 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 2) is 2
# 2025-12-08 18:30:23.795 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 4) is 10
# 2025-12-08 18:30:23.796 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 6) is 11
# 2025-12-08 18:30:23.796 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 8) is 11
# 2025-12-08 18:30:23.796 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 10) is 2
# 2025-12-08 18:30:23.796 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 11) is 1
# 2025-12-08 18:30:23.796 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 12) is 1
# 2025-12-08 18:30:23.797 | DEBUG    | __main__:analyze:67 - Beam in pos (15, 14) is 1
# 2025-12-08 18:30:23.797 | DEBUG    | __main__:show_diagram:76 -
# .......S.......
# .......1.......
# ......1^1......
# ......1.1......
# .....1^2^1.....
# .....1.2.1.....
# ....1^3^3^1....
# ....1.3.3.1....
# ...1^4^331^1...
# ...1.4.331.1...
# ..1^5^434^2^1..
# ..1.5.434.2.1..
# .1^154^74.21^1.
# .1.154.74.21.1.
# 1^2^10^11^11^211^1
# 1.2.10.11.11.211.1
# 2025-12-08 18:30:23.797 | INFO     | __main__:analyze:72 - Part 2 took: 31.72ms
# 2025-12-08 18:30:23.797 | INFO     | __main__:analyze:73 - Result is n timelines = 40

# %%
Qman = QuantumTachyonManifold(raw_data, is_example = False)
Qman.analyze()
# Out:
# 2025-12-08 18:30:48.667 | INFO     | __main__:analyze:72 - Part 2 took: 20.18ms
# 2025-12-08 18:30:48.668 | INFO     | __main__:analyze:73 - Result is n timelines = 25592971184998
